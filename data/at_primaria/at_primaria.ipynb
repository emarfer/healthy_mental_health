# %%
import pandas as pd
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.~lock.at_prim.xlsx#',
#  'at_prim.xlsx',
#  'at_primaria.csv',
#  'at_primaria.ipynb',
#  'Tabla-5b40b18c-f5d4-4f61-9baa-be94c2560b2d.csv',
#  'Tabla-87e61456-a19c-438e-ae6b-20af2db68a62.xls']

# %%
at_prim = pd.read_excel('at_prim.xlsx')

# %%
at_prim
# Out:
#         Año         CCAA    Sexo     Nivel Renta  Situación Laboral  \
# 0      2011    02-Aragón  Hombre  Sin Clasificar  Otras situaciones
# 1      2011    02-Aragón  Hombre  Sin Clasificar  Otras situaciones
# 2      2011    02-Aragón  Hombre  Sin Clasificar  Otras situaciones
# 3      2011    02-Aragón  Hombre  Sin Clasificar  Otras situaciones
# 4      2011    02-Aragón   Mujer  Sin Clasificar  Otras situaciones
# ...     ...          ...     ...             ...                ...
# 13330  2019  17-La Rioja   Mujer        Muy baja  Otras situaciones
# 13331  2019  17-La Rioja   Mujer        Muy baja  Otras situaciones
# 13332  2019  17-La Rioja   Mujer  Sin Clasificar  Otras situaciones
# 13333  2019  17-La Rioja   Mujer  Sin Clasificar  Otras situaciones
# 13334  2019  17-La Rioja   Mujer  Sin Clasificar  Otras situaciones
#
#       Grandes Grupos     Casos  Casos por mil personas asignadas  \
# 0         00-14 años   15124.0                            162.59
# ...

# %%
at_prim['Nivel Renta'].value_counts()
# Out:
# <18.000 ? /año          3720
# 18.000-99.999 ? /año    3638
# Muy baja                2779
# ?100.000 ? /año         2056
# Sin Clasificar          1142
# Name: Nivel Renta, dtype: int64
